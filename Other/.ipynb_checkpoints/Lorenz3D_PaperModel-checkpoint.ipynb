# %%
#Author Maria Giselle Fernandez-Godino
#email: mariagisellefernandez@gmail.com

# %%
import os
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, LSTM, Bidirectional, RepeatVector, TimeDistributed, Flatten
from sklearn.model_selection import train_test_split

# %%
n=100000
m=1000
total=n+m
delta_t=0.01
s=5

def lorenz(v1, v2, v3, a=10, b=8/3, r=28):
    '''
    Given:
       x, y, z: a point of interest in three dimensional space
       s, r, b: parameters defining the lorenz attractor
    Returns:
       x_dot, y_dot, z_dot: values of the lorenz attractor's partial
           derivatives at the point x, y, z
    '''
    v1_dot = a*(v2-v1)
    v2_dot = -a*v1 - v2 - v2*v3
    v3_dot = v1*v2 - b*v3 - b*(r+a)
    return v1_dot, v2_dot, v3_dot

# Need one more for the initial values
xs = np.empty(total + 1)
ys = np.empty(total + 1)
zs = np.empty(total + 1)

# Set initial values
xs[0], ys[0], zs[0] = (0., 3., 8.)

# Step through "time", calculating the partial derivatives at the current point
# and using them to estimate the next point
for i in range(total):
    x_dot, y_dot, z_dot = lorenz(xs[i], ys[i], zs[i])
    xs[i + 1] = xs[i] + (x_dot * delta_t)
    ys[i + 1] = ys[i] + (y_dot * delta_t)
    zs[i + 1] = zs[i] + (z_dot * delta_t)

# %%
# Plot
fig = plt.figure()
ax = fig.gca(projection='3d')

ax.plot(xs, ys, zs, lw=0.5)
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")
ax.set_zlabel("Z Axis")
ax.set_title("Lorenz Attractor")

plt.show()

# %%
# Scaled to work with Neural networks.
xs_scaled = (xs-np.min(xs))/(np.max(xs)-np.min(xs))
ys_scaled = (ys-np.min(ys))/(np.max(ys)-np.min(ys))
zs_scaled = (zs-np.min(zs))/(np.max(zs)-np.min(zs))

# %%
# Plot
fig = plt.figure()
ax = fig.gca(projection='3d')

ax.plot(xs_scaled, ys_scaled, zs_scaled, lw=0.5)
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")
ax.set_zlabel("Z Axis")
ax.set_title("Lorenz Attractor")

plt.show()

# %%
xs1_train = []
xs2_train = []
for i in range(s,n):
    xs1_train.append(xs_scaled[i-s:i])
    xs2_train.append(xs_scaled[i])
xs1_train, xs2_train = np.array(xs1_train), np.array(xs2_train)

# %%
ys1_train = []
ys2_train = []
for i in range(s,n):
    ys1_train.append(ys_scaled[i-s:i])
    ys2_train.append(ys_scaled[i])
ys1_train, ys2_train = np.array(ys1_train), np.array(ys2_train)

# %%
zs1_train = []
zs2_train = []
for i in range(s,n):
    zs1_train.append(zs_scaled[i-s:i])
    zs2_train.append(zs_scaled[i])
zs1_train, zs2_train = np.array(zs1_train), np.array(zs2_train)

# %%
print(xs2_train[-1])
print(ys2_train[-1])
print(zs2_train[-1])
# Out:
# 0.5366370836113854
# 0.6506635944097597
# 0.19659083226726795

# %%
def LSTM_model(input_):
    print('encoder')
    print(input_.shape)
    x = LSTM(128, input_shape=(s,3), return_sequences=True)(input_)
    print(x.shape)
    x = Flatten()(x)
    print(x.shape)
    x = RepeatVector(10)(x)
    print(x.shape)
    x = LSTM(128)(x)
    print(x.shape)
    x = TimeDistributed(Dense(128))(x)
    print(x.shape)
    output = TimeDistributed(Dense(3,activation="sigmoid"))(x)
    print(output.shape)
    return output

# %%
input_ = tensorflow.keras.Input(shape=(s,3))
LSTM_model = tensorflow.keras.Model(input_, LSTM_model(input_))
# Out:
# encoder
# (None, 5, 3)
# (None, 5, 128)
# (None, 640)
# (None, 10, 640)
# (None, 128)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-71c23c3757b4> in <module>
#       1 input_ = tensorflow.keras.Input(shape=(s,3))
# ----> 2 LSTM_model = tensorflow.keras.Model(input_, LSTM_model(input_))
#
# <ipython-input-12-067f12a1a108> in LSTM_model(input_)
#      10     x = LSTM(128)(x)
#      11     print(x.shape)
# ---> 12     x = TimeDistributed(Dense(128))(x)
#      13     print(x.shape)
#      14     output = TimeDistributed(Dense(3,activation="sigmoid"))(x)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     949     # >> model = tf.keras.Model(inputs, outputs)
#     950     if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
# --> 951       return self._functional_construction_call(inputs, args, kwargs,
#     952                                                 input_list)
#     953
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    1088           layer=self, inputs=inputs, build_graph=True, training=training_value):
#    1089         # Check input assumptions set after layer building, e.g. input shape.
# -> 1090         outputs = self._keras_tensor_symbolic_call(
#    1091             inputs, input_masks, args, kwargs)
#    1092
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py in _keras_tensor_symbolic_call(self, inputs, input_masks, args, kwargs)
#     820       return nest.map_structure(keras_tensor.KerasTensor, output_signature)
#     821     else:
# --> 822       return self._infer_output_signature(inputs, args, kwargs, input_masks)
#     823
#     824   def _infer_output_signature(self, inputs, args, kwargs, input_masks):
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py in _infer_output_signature(self, inputs, args, kwargs, input_masks)
#     860           # overridden).
#     861           # TODO(kaftan): do we maybe_build here, or have we already done it?
# --> 862           self._maybe_build(inputs)
#     863           outputs = call_fn(inputs, *args, **kwargs)
#     864
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py in _maybe_build(self, inputs)
#    2708         # operations.
#    2709         with tf_utils.maybe_init_scope(self):
# -> 2710           self.build(input_shapes)  # pylint:disable=not-callable
#    2711       # We must set also ensure that the layer is marked as built, and the build
#    2712       # shape is stored since user defined build functions may not be calling
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/layers/wrappers.py in build(self, input_shape)
#     173     input_shape = tensor_shape.TensorShape(input_shape).as_list()
#     174     if len(input_shape) < 3:
# --> 175       raise ValueError(
#     176           '`TimeDistributed` Layer should be passed an `input_shape ` '
#     177           'with at least 3 dimensions, received: ' + str(input_shape))
#
# ValueError: `TimeDistributed` Layer should be passed an `input_shape ` with at least 3 dimensions, received: [None, 128]

# %%
RepeatVector?

# %%
opt = tensorflow.keras.optimizers.Adam()
LSTM_model.compile(optimizer=opt, loss='mse')
LSTM_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 5, 3)]            0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 5, 256)            135168
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 256)               394240
# _________________________________________________________________
# dense (Dense)                (None, 3)                 771
# =================================================================
# Total params: 530,179
# Trainable params: 530,179
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_train=np.concatenate((xs1_train.reshape(-1,s,1), ys1_train.reshape(-1,s,1), zs1_train.reshape(-1,s,1)), axis=2)
y_train=np.concatenate((xs2_train.reshape(-1,1),ys2_train.reshape(-1,1),zs2_train.reshape(-1,1)),axis=1)

# %%
X_train.shape
# Out:
# (99995, 5, 3)

# %%
y_train.shape
# Out:
# (99995, 3)

# %%
epochs=20
LSTM_model.fit(X_train,y_train,epochs=epochs,batch_size=128)
# Out:
# Epoch 1/20
# 782/782 [==============================] - 28s 31ms/step - loss: 0.0040
# Epoch 2/20
# 782/782 [==============================] - 26s 34ms/step - loss: 2.0473e-05
# Epoch 3/20
# 782/782 [==============================] - 24s 31ms/step - loss: 1.3273e-05
# Epoch 4/20
# 782/782 [==============================] - 23s 29ms/step - loss: 8.7298e-06
# Epoch 5/20
# 782/782 [==============================] - 24s 31ms/step - loss: 6.6577e-06
# Epoch 6/20
# 782/782 [==============================] - 23s 30ms/step - loss: 4.9308e-06
# Epoch 7/20
# 782/782 [==============================] - 23s 29ms/step - loss: 4.5719e-06
# Epoch 8/20
# 782/782 [==============================] - 24s 31ms/step - loss: 4.1243e-06
# Epoch 9/20
# 782/782 [==============================] - 22s 28ms/step - loss: 3.6979e-06
# Epoch 10/20
# 782/782 [==============================] - 23s 30ms/step - loss: 2.7525e-06
# Epoch 11/20
# 782/782 [==============================] - 23s 29ms/step - loss: 2.8067e-06
# Epoch 12/20
# 782/782 [==============================] - 24s 31ms/step - loss: 4.4116e-06
# Epoch 13/20
# 782/782 [==============================] - 23s 29ms/step - loss: 3.9916e-06
# Epoch 14/20
# 782/782 [==============================] - 22s 29ms/step - loss: 3.5318e-06
# Epoch 15/20
# 782/782 [==============================] - 23s 29ms/step - loss: 3.2451e-06
# Epoch 16/20
# 782/782 [==============================] - 23s 29ms/step - loss: 1.8537e-06
# Epoch 17/20
# 782/782 [==============================] - 22s 29ms/step - loss: 2.2759e-06
# Epoch 18/20
# 782/782 [==============================] - 23s 30ms/step - loss: 3.8430e-06
# Epoch 19/20
# 782/782 [==============================] - 27s 35ms/step - loss: 2.8596e-06
# Epoch 20/20
# 782/782 [==============================] - 25s 32ms/step - loss: 2.5403e-06

# %%
#LSTM_model.save('LSTM_model.h5')

# %%
import tensorflow as tf
LSTM_model = tf.keras.models.load_model('LSTM_model.h5')

# %%
y_train_pred=LSTM_model.predict(X_train)

# %%
y_train_pred.shape
# Out:
# (99995, 3)

# %%
# Plot
fig = plt.figure()
ax = fig.gca(projection='3d')

ax.plot(y_train_pred[:,0], y_train_pred[:,1], y_train_pred[:,2], lw=0.5)
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")
ax.set_zlabel("Z Axis")
ax.set_title("Lorenz Attractor")

plt.show()

# %%
plt.plot(np.linspace(0,n,n),xs_scaled[:n],label='True')
plt.plot(np.linspace(s,n,n-s),y_train_pred[:,0],label='Predicted original')
plt.legend()
plt.xlim([99900,100000])
# Out:
# (99900.0, 100000.0)

# %%
np.linspace(s,len(xs_scaled),len(xs_scaled)-s-1).shape
# Out:
# (100095,)

# %%
plt.plot(np.linspace(0,n,n),ys_scaled[:n],label='True')
plt.plot(np.linspace(s,n,n-s),y_train_pred[:,1],label='Predicted original')
plt.legend()
#plt.xlim([0,100])
plt.xlim([99900,100000])
# Out:
# (99900.0, 100000.0)

# %%
plt.plot(np.linspace(0,n,n),zs_scaled[:n],label='True')
plt.plot(np.linspace(s,n,n-s),y_train_pred[:,2],label='Predicted original')
plt.legend()
#plt.xlim([0,200])
plt.xlim([99900,100000])
# Out:
# (99900.0, 100000.0)

# %% [markdown]
# ## Predicting the future

# %%
# Plot
fig = plt.figure()
ax = fig.gca(projection='3d')

ax.plot(xs_scaled[n:n+m], ys_scaled[n:n+m], zs_scaled[n:n+m], lw=0.5)
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")
ax.set_zlabel("Z Axis")
ax.set_title("Lorenz Attractor")

plt.show()

# %%
print(xs_scaled[n:n+m][0])
print(ys_scaled[n:n+m][0])
print(zs_scaled[n:n+m][0])
# Out:
# 0.5486638293106105
# 0.6591834912123266
# 0.18690398394432922

# %%
xs1_f = []; xs2_f = []
ys1_f = []; ys2_f = []
zs1_f = []; zs2_f = []

xs1_f.append(X_train[-1,:,0])
ys1_f.append(X_train[-1,:,1])
zs1_f.append(X_train[-1,:,2])

yf=[]

for j in range(m):
    X1 = np.concatenate((xs1_f[-1].reshape(-1,s,1), ys1_f[-1].reshape(-1,5,1), zs1_f[-1].reshape(-1,5,1)), axis=2)
    y_f = LSTM_model.predict(X1)
    xs2_f.append(y_f[0][0]); ys2_f.append(y_f[0][1]); zs2_f.append(y_f[0][2])
    a=np.hstack((X1[0,1:,:].reshape(1,4,3),y_f[-1].reshape(1,1,3)))   
    xs1_f.append(a[0][:,0]); ys1_f.append(a[0][:,1]); zs1_f.append(a[0][:,2])

# %%
print(xs2_f[0])
print(ys2_f[0])
print(zs2_f[0])
# Out:
# 0.5361769
# 0.65019697
# 0.19681904

# %%
# Plot
fig = plt.figure()
ax = fig.gca(projection='3d')

ax.plot(xs2_f, ys2_f, zs2_f, lw=0.5)
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")
ax.set_zlabel("Z Axis")
ax.set_title("Lorenz Attractor")

plt.show()

# %%
plt.plot(np.linspace(0,m,m),xs_scaled[n:n+m],label='True')
plt.plot(np.linspace(s-1,m,m-s),xs2_f[s:],label='Predicted original')
plt.legend()
plt.xlim([0,1000])
# Out:
# (0.0, 1000.0)

# %%
plt.plot(np.linspace(0,m,m),ys_scaled[n:n+m],label='True')
plt.plot(np.linspace(s-1,m,m-s),ys2_f[s:],label='Predicted original')
plt.legend()
plt.xlim([0,1000])
# Out:
# (0.0, 1000.0)

# %%
plt.plot(np.linspace(0,m,m),zs_scaled[n:n+m],label='True')
plt.plot(np.linspace(s-1,m,m-s),zs2_f[s:],label='Predicted original')
plt.legend()
plt.xlim([0,1000])
# Out:
# (0.0, 1000.0)
